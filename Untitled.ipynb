# %%
import numpy as np
import pandas as pd

# %%
dat = pd.read_csv('dat.csv')
dat
# Out:
#        Unnamed: 0 session_date symbol scan_phase  flagged  faded direction  \
# 0               0   2026-06-15   SLBT   backfill     True  False      down
# 1               1   2026-06-15   SKYQ   backfill     True  False      down
# 2               2   2026-06-15     QH   backfill     True  False      down
# 3               3   2026-06-15   IREZ   backfill     True  False      down
# 4               4   2026-06-15   RGTZ   backfill     True  False      down
# ...           ...          ...    ...        ...      ...    ...       ...
# 19122       32514   2026-09-14   CONL   backfill     True  False        up
# 19123       32515   2026-09-14   STXL   backfill     True  False      down
# 19124       32516   2026-09-14   BMNG   backfill     True  False      down
# 19125       32517   2026-09-14   BMNU   backfill     True  False      down
# 19126       32518   2026-09-14   CNTB   backfill     True  False      down
#
# ...

# %%
dat.columns
# Out:
# Index(['Unnamed: 0', 'session_date', 'symbol', 'scan_phase', 'flagged',
#        'faded', 'direction', 'methods', 'prev_close', 'gap_pct', 'gap_atr',
#        'gap_sigma', 'atr', 'spread_pct', 'has_news', 'news_count',
#        'looks_earnings', 'entry_basis', 'entry_date', 'entry_price',
#        'max_favourable_pct', 'max_adverse_pct', 'target_price', 'target_pct',
#        'target_basis', 'stop_price', 'stop_pct', 'exit_reason', 'exit_day',
#        'exit_price', 'ambiguous', 'strategy_return_pct', 'cost_pct',
#        'net_strategy_return_pct', 'forward_bars', 'top_headline',
#        'direction_scan', 'prev_close_scan', 'prev_session_date', 'prev_volume',
#        'ref_price', 'ref_source', 'gap_pct_scan', 'atr_scan', 'atr_samples',
#        'gap_atr_scan', 'overnight_mean_pct', 'overnight_stdev_pct',
#        'gap_sigma_scan', 'sigma_samples', 'bid', 'ask', 'spread_pct_scan',
#        'premarket_volume', 'premarket_high', 'premarket_low', 'premarket_last',
# ...

# %%
dat['net_strategy_return_pct']
# Out:
# 0        117.614740
# 1         49.433194
# 2         48.620315
# 3         48.351695
# 4         47.438883
#             ...
# 19122    -12.103964
# 19123    -12.269389
# 19124    -14.451176
# 19125    -14.708441
# 19126    -16.016116
# Name: net_strategy_return_pct, Length: 19127, dtype: float64

# %%
ax1 = dat.plot.scatter(x="direction", y="net_strategy_return_pct", c="DarkBlue")

# %%
ax1 = dat.plot.scatter(x="atr_samples", y="net_strategy_return_pct", c="DarkBlue")
